# %%
r1=float(input("r1="))
r2=float(input("r2="))
rs=r1+r2
print(rs)
# Out:
# r1= 10
# r2= 5
# 15.0

# %%
r1=float(input("r1="))
r2=float(input("r2="))
rp = 1/(1/r1) + (1/r2)
print(rp)
# Out:
# r1= 2
# r2= 4
# 2.25

# %%
i=20
r=30
v=i*r
print(v)
# Out:
# 600

# %%
R1 = (float(input("R1: ")))
R2 = (float(input("R2: ")))
Rs = (R1+R2)
print(Rs)
# Out:
# R1:  2
# R2:  5
# 7.0

# %%
I = float(input("I: "))
R = float(input("R: "))
V = I * R
print(V)
# Out:
# I:  2
# R:  40
# 80.0
